# %% [markdown]
# # pandas 실습

# %%
import numpy as np

# %%
import pandas as pd

# %% [markdown]
# - pandas는 행과 열을 레이블로 식벼르 여러 가지 타입 허용 - numpy보다 사용 쉽다

# %% [markdown]
# - numpy는 행/열이 단순 정수형 인덱스, 단일 데이터 타입 - low레벨에서 더 효율적

# %% [markdown]
# - Series 객체 - 인텍스를 갖는 1차원 배열

# %%
np.random.randint(100, size = (5,2))
# Out:
# array([[42, 25],
#        [57, 53],
#        [27, 12],
#        [60, 56],
#        [41,  5]])

# %%
x = pd.DataFrame(np.random.randint(100, size = (100,2))),

# %%
x.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
x.columns
# Out:
# RangeIndex(start=0, stop=2, step=1)

# %%
x.values
# Out:
# array([[44, 16],
#        [86, 80],
#        [ 5, 76],
#        [10, 31],
#        [54,  2],
#        [29,  9],
#        [45, 68],
#        [66, 19],
#        [73, 76],
#        [94, 99],
#        [45,  6],
#        [31,  6],
#        [16, 76],
#        [16, 40],
#        [17, 37],
#        [15, 88],
#        [50, 45],
#        [27,  0],
#        [76, 29],
#        [68, 42],
#        [45, 84],
#        [ 0, 78],
#        [50, 69],
#        [84, 35],
#        [70,  1],
#        [80, 11],
#        [33, 18],
#        [32, 78],
#        [81, 95],
#        [81, 85],
#        [19, 93],
#        [35, 54],
#        [67, 90],
#        [15, 64],
#        [41, 32],
#        [64, 28],
#        [30, 12],
#        [88, 75],
#        [32, 39],
#        [65, 50],
#        [ 6, 70],
#        [74, 93],
#        [78, 32],
#        [18,  7],
#        [71, 82],
#        [26, 17],
#        [47, 54],
#        [20, 42],
#        [46,  0],
#        [37, 23],
#        [29, 43],
#        [92, 31],
# ...

# %%
df = pd.DataFrame([[1,2,3],[4,5,6]],columns = ['x','y','z'])

# %%
df
# Out:
#    x  y  z
# 0  1  2  3
# 1  4  5  6

# %%
df = pd.DataFrame({'x':np.random.choice(['a','b','c'],size = 10),'y':np.random.randn(10)},index = np.arange(1,11))

# %% [markdown]
# ## 수업 놓침 강의 참고 할 것

# %%
df
# Out:
#     x         y
# 1   c -2.199415
# 2   b -0.565395
# 3   c  2.468611
# 4   a -0.270902
# 5   b -0.209627
# 6   a -1.614594
# 7   a  0.352789
# 8   a  0.685723
# 9   b -2.279742
# 10  a -0.779835

# %%
auto = pd.read_csv("Data2020\\Auto.csv")

# %%
auto
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0        130    3504          12.0    70
# 1    15.0          8         350.0        165    3693          11.5    70
# 2    18.0          8         318.0        150    3436          11.0    70
# 3    16.0          8         304.0        150    3433          12.0    70
# 4    17.0          8         302.0        140    3449          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 392  27.0          4         140.0         86    2790          15.6    82
# 393  44.0          4          97.0         52    2130          24.6    82
# 394  32.0          4         135.0         84    2295          11.6    82
# 395  28.0          4         120.0         79    2625          18.6    82
# 396  31.0          4         119.0         82    2720          19.4    82
#
#      origin                       name
# 0         1  chevrolet chevelle malibu
# ...

# %%
x
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0        130    3504          12.0    70
# 1    15.0          8         350.0        165    3693          11.5    70
# 2    18.0          8         318.0        150    3436          11.0    70
# 3    16.0          8         304.0        150    3433          12.0    70
# 4    17.0          8         302.0        140    3449          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 392  27.0          4         140.0         86    2790          15.6    82
# 393  44.0          4          97.0         52    2130          24.6    82
# 394  32.0          4         135.0         84    2295          11.6    82
# 395  28.0          4         120.0         79    2625          18.6    82
# 396  31.0          4         119.0         82    2720          19.4    82
#
#      origin                       name
# 0         1  chevrolet chevelle malibu
# ...

# %%
x.head(2)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0        130    3504          12.0    70
# 1  15.0          8         350.0        165    3693          11.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320

# %%
x.tail(1)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 396  31.0          4         119.0         82    2720          19.4    82
#
#      origin        name
# 396       1  chevy s-10

# %% [markdown]
# - x['mid']와 x.mid는 서로 같지만 x.mid는 null이 존재시 사용불가

# %%
x
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0        130    3504          12.0    70
# 1    15.0          8         350.0        165    3693          11.5    70
# 2    18.0          8         318.0        150    3436          11.0    70
# 3    16.0          8         304.0        150    3433          12.0    70
# 4    17.0          8         302.0        140    3449          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 392  27.0          4         140.0         86    2790          15.6    82
# 393  44.0          4          97.0         52    2130          24.6    82
# 394  32.0          4         135.0         84    2295          11.6    82
# 395  28.0          4         120.0         79    2625          18.6    82
# 396  31.0          4         119.0         82    2720          19.4    82
#
#      origin                       name
# 0         1  chevrolet chevelle malibu
# ...

# %%
x.iloc[0:3,:]
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0        130    3504          12.0    70
# 1  15.0          8         350.0        165    3693          11.5    70
# 2  18.0          8         318.0        150    3436          11.0    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
